# %% [markdown]
# ## Задание 1.1. Оформление ноутбука

# %% [markdown]
# ### Давайте познакомиться

# %% [markdown]
# Добрый вечер!
#
# Меня зовут Дмитрий.
#
# Я давно работаю аналитиком, но аналитиком не в сфере IT. В прошлом году решил попробовать себя в этой сфере: поэтому начал закрывать деицитную ведомость с цифровых компетенций.
#
# Так как python мне дается, мягко говоря, тяжело, буду благодарен за обратную связь по заданиям.
